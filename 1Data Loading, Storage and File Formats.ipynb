# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("sales_data_sample.csv" ,     encoding="latin1")
df2 = pd.read_json('sales.json')
df3 = pd.read_excel('sales_data_sample.xlsx')

# %%
df1.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (2823, 25)
# (2823, 25)
# (2823, 25)

# %%
df2.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue                          NYC    NY
# ...

# %%
df1.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df1 = df1.drop(['TERRITORY' , 'STATE' , 'ADDRESSLINE2'] , axis=1)

# %%
df2 = df2.drop([ 'STATE' , 'ADDRESSLINE2'] , axis=1)

# %%
df2['TERRITORY'].fillna('Unknown', inplace=True)

# %%
import seaborn as sns

# %%
sns.histplot(x="STATUS" , data=df1)
# Out:
# <Axes: xlabel='STATUS', ylabel='Count'>

# %%
sns.histplot(x='MONTH_ID', data=df1 )
# Out:
# <Axes: xlabel='MONTH_ID', ylabel='Count'>

# %%
sns.scatterplot(x="STATUS"  , y="MONTH_ID" ,hue="COUNTRY" ,data = df1)
plt.legend(bbox_to_anchor=(1, 1), loc=2)
import matplotlib as plt

# %%
ddf1 = df1[df1["STATUS"] == 'Shipped']
ddf1.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PRODUCTCODE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...    S10_1678
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...    S10_1678
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...    S10_1678
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...    S10_1678
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
# Convert ORDERDATE to datetime if it’s not already
df1['ORDERDATE'] = pd.to_datetime(df1['ORDERDATE'])

# %%
# Deriving TOTALSALES as QUANTITYORDERED * PRICEEACH
df1['TOTALSALES'] = df1['QUANTITYORDERED'] * df1['PRICEEACH']

# %%
total_sales = df1['TOTALSALES'].sum()
avg_order_value = df1['TOTALSALES'].mean()
sales_by_category = df1.groupby('PRODUCTLINE')['TOTALSALES'].sum()

# %%
import matplotlib.pyplot as plt

# Total sales by product line
sales_by_category.plot(kind='bar', color='skyblue', title='Total Sales by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Total Sales')
plt.show()

# %%
# Distribution of deal sizes
df1['DEALSIZE'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Deal Size Distribution')
plt.show()

# %%
df = df1
df.groupby(df['ORDERDATE'].dt.to_period('M'))['TOTALSALES'].sum().plot(kind='line', title='Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()
